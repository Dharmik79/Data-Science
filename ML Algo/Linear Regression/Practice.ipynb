# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
sns.scatterplot(x='area',y='price',data=df,color='r',marker='+')
# Out:
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
lr=LinearRegression()
area=df.area
price=df.price
lr.fit(area[0],price[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-d81fa5a99c98> in <module>
#       2 area=df.area
#       3 price=df.price
# ----> 4 lr.fit(area[0],price[0])
#
# ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~/.local/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-ecc9e7252b11> in <module>
# ----> 1 lr.predict([3300])
#
# ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     218         check_is_fitted(self)
#     219
# --> 220         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     221         return safe_sparse_dot(X, self.coef_.T,
#     222                                dense_output=True) + self.intercept_
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
# ...
