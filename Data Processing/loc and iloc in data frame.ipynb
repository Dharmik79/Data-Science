# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd
import numpy as np

# %%
data=pd.Series(['a','b','c','d','e'],index=[10,23,4,5,6])
data
# Out:
# 10    a
# 23    b
# 4     c
# 5     d
# 6     e
# dtype: object

# %%
data[10]
# Out:
# 'a'

# %%
data[1:3]
# Out:
# 23    b
# 4     c
# dtype: object

# %%
data.loc[4]
# Out:
# 'c'

# %% [markdown]
# ### Explicit index
# #### In this the final index is included

# %%
data.loc[4:5]
# Out:
# 4    c
# 5    d
# dtype: object

# %% [markdown]
# ### iloc is used when the search is based on row number

# %%
data.iloc[1]
# Out:
# 'b'

# %%
data.iloc[2:4]
# Out:
# 4    c
# 5    d
# dtype: object
