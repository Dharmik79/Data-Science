# %%
import numpy as np
import pandas as pd

# %%
met=np.array([[200,220,250],[68,79,105],[110,140,180],[80,85,90]])
met
# Out:
# array([[200, 220, 250],
#        [ 68,  79, 105],
#        [110, 140, 180],
#        [ 80,  85,  90]])

# %% [markdown]
# ### Dot product in numpy

# %%
np.dot(75,met)
# Out:
# array([[15000, 16500, 18750],
#        [ 5100,  5925,  7875],
#        [ 8250, 10500, 13500],
#        [ 6000,  6375,  6750]])

# %%
sold=np.array([[50,60,25],[10,13,5],[40,70,52]])
price_per_unit=np.array([20,30,15])

# %%
sold
# Out:
# array([[50, 60, 25],
#        [10, 13,  5],
#        [40, 70, 52]])

# %%
price_per_unit
# Out:
# array([20, 30, 15])

# %%
np.dot(price_per_unit,sold)
# Out:
# array([1900, 2640, 1430])
