# %% [markdown]
# ### Importing necessary libraries

# %%
import numpy as np
import pandas as pd

# %%
import tensorflow as tf

# %%
data=pd.Series([1,2,3,4,5,6],index=['d','b','c','q','r','y'])
data
# Out:
# d    1
# b    2
# c    3
# q    4
# r    5
# y    6
# dtype: int64

# %%
data1=data.reindex(index=['q','b','c','d','r','y'])
data1
# Out:
# q    4
# b    2
# c    3
# d    1
# r    5
# y    6
# dtype: int64

# %%
data.reindex(index=np.arange(6))
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# dtype: float64

# %%
data4=pd.DataFrame(np.arange(9).reshape((3,3)),index=['a','d','c'],columns=['Andhra','TamilNadu','Kerala'])
data4
# Out:
#    Andhra  TamilNadu  Kerala
# a       0          1       2
# d       3          4       5
# c       6          7       8

# %%
data5=data4.reindex(index=['a','b','c','d'])
data5
# Out:
#    Andhra  TamilNadu  Kerala
# a     0.0        1.0     2.0
# b     NaN        NaN     NaN
# c     6.0        7.0     8.0
# d     3.0        4.0     5.0

# %%
capitals=['MP','Andhra','TamilNadu','Kerala']
data5=data5.reindex(columns=capitals)
data5
# Out:
#    MP  Andhra  TamilNadu  Kerala
# a NaN     0.0        1.0     2.0
# b NaN     NaN        NaN     NaN
# c NaN     6.0        7.0     8.0
# d NaN     3.0        4.0     5.0

# %%
data5.loc[['a','b','c','d']]
# Out:
#    MP  Andhra  TamilNadu  Kerala
# a NaN     0.0        1.0     2.0
# b NaN     NaN        NaN     NaN
# c NaN     6.0        7.0     8.0
# d NaN     3.0        4.0     5.0

# %% [markdown]
# ### Dropping values in pandas

# %%
d1=pd.DataFrame(np.arange(9).reshape((3,3)),index=['a','d','c'],columns=['Andhra','TamilNadu','Kerala'])
d1
# Out:
#    Andhra  TamilNadu  Kerala
# a       0          1       2
# d       3          4       5
# c       6          7       8

# %%
d1.drop('a')
# Out:
#    Andhra  TamilNadu  Kerala
# d       3          4       5
# c       6          7       8

# %%
d1
# Out:
#    Andhra  TamilNadu  Kerala
# a       0          1       2
# d       3          4       5
# c       6          7       8

# %%
d2=d1.drop(['a','d'])
d2
# Out:
#    Andhra  TamilNadu  Kerala
# c       6          7       8

# %%
d3=d1.drop('Kerala',axis=1)
d3
# Out:
#    Andhra  TamilNadu
# a       0          1
# d       3          4
# c       6          7

# %%
d3=d1.drop('Kerala',axis='columns')
d3
# Out:
#    Andhra  TamilNadu
# a       0          1
# d       3          4
# c       6          7

# %% [markdown]
# #### Adding values in series

# %%
ser1=pd.Series([1,2,3,4,5],index=['a','c','d','e','g'])
ser2=pd.Series([2,6,8,0,5],index=['a','v','e','d','g'])

ser1+ser2
# Out:
# a     3.0
# c     NaN
# d     3.0
# e    12.0
# g    10.0
# v     NaN
# dtype: float64

# %%
df3=pd.DataFrame({'A':[1,2]})
df3
# Out:
#    A
# 0  1
# 1  2

# %% [markdown]
# ### Treating null values

# %%
df5=pd.DataFrame(np.arange(20).reshape((4,5)),columns=list('abcde'))
df5
# Out:
#     a   b   c   d   e
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19

# %%
df5.loc[1,'d']=np.nan
df6=df5
df6
# Out:
#     a   b   c     d   e
# 0   0   1   2   3.0   4
# 1   5   6   7   NaN   9
# 2  10  11  12  13.0  14
# 3  15  16  17  18.0  19

# %%
df5+df6
# Out:
#     a   b   c     d   e
# 0   0   2   4   6.0   8
# 1  10  12  14   NaN  18
# 2  20  22  24  26.0  28
# 3  30  32  34  36.0  38

# %% [markdown]
# ### lambda functions in dataframe

# %%
df4=pd.DataFrame(np.random.randn(12).reshape((3,4)),index=['one','two','three'],columns=['Hoo','muu','qqw','iiit'])
df4
# Out:
#             Hoo       muu       qqw      iiit
# one    0.188724  1.924790  0.672624 -0.010763
# two   -0.207270 -0.499958 -0.954370 -0.340513
# three -1.004842  0.401979 -1.151506  0.014892

# %%
abs(df4)
# Out:
#             Hoo       muu       qqw      iiit
# one    0.188724  1.924790  0.672624  0.010763
# two    0.207270  0.499958  0.954370  0.340513
# three  1.004842  0.401979  1.151506  0.014892

# %%
f=lambda x: x.max()
df4.apply(f,axis=0)
# Out:
# Hoo     0.188724
# muu     1.924790
# qqw     0.672624
# iiit    0.014892
# dtype: float64

# %%
def f(x):
    return pd.Series([x.max(),x.mean(),x.min()],index=['max','mean','min'])

# %%
df4.apply(f)
# Out:
#            Hoo       muu       qqw      iiit
# max   0.188724  1.924790  0.672624  0.014892
# mean -0.341129  0.608937 -0.477750 -0.112128
# min  -1.004842 -0.499958 -1.151506 -0.340513

# %%
f=lambda x: '%.3f' %x
df4.applymap(f)
# Out:
#           Hoo     muu     qqw    iiit
# one     0.189   1.925   0.673  -0.011
# two    -0.207  -0.500  -0.954  -0.341
# three  -1.005   0.402  -1.152   0.015

# %% [markdown]
# ### Sorting and Ranking

# %%
series=pd.Series(np.arange(6),index=['a','n','d','w','r','y'])
series
# Out:
# a    0
# n    1
# d    2
# w    3
# r    4
# y    5
# dtype: int32

# %%
series.sort_index(axis=0,level=None,ascending=True)
# Out:
# a    0
# d    2
# n    1
# r    4
# w    3
# y    5
# dtype: int32
