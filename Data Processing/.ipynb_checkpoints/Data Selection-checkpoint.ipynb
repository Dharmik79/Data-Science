# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Checking version

# %%
pd.__version__
# Out:
# '1.0.5'

# %%
data=pd.Series([10,20,30,40,50,60,70,80,90],index=["A","B","C","D","E","F","G","H","I"])

# %%
data
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# F    60
# G    70
# H    80
# I    90
# dtype: int64

# %% [markdown]
# #### Accessing the value of index A

# %%
data['A']
# Out:
# 10

# %% [markdown]
# #### Checking index A is present in data

# %%
'A' in data
# Out:
# True

# %%
'Q' in data
# Out:
# False

# %%
pd.Series.keys?

# %%
data.keys()
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I'], dtype='object')

# %%
list(data.items())
# Out:
# [('A', 10),
#  ('B', 20),
#  ('C', 30),
#  ('D', 40),
#  ('E', 50),
#  ('F', 60),
#  ('G', 70),
#  ('H', 80),
#  ('I', 90)]

# %% [markdown]
# ### Data Selection using Implicit and Explicit method

# %%
data
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# F    60
# G    70
# H    80
# I    90
# dtype: int64

# %%
data['A':'D']
# Out:
# A    10
# B    20
# C    30
# D    40
# dtype: int64

# %%
data[0:5]
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
data[['A','E']]
# Out:
# A    10
# E    50
# dtype: int64
